# %%
from urllib.request import urlopen, Request, urlretrieve
from bs4 import BeautifulSoup

url = 'http://www.uniqlo.com/tw/store/feature/uq/alias/v2/ajaxAliasItem.jsp?dispLayerInfo=%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F10%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F08%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F02%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F09%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F05%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F01%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F04%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F23%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F25%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F11%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F22%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F26%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F24%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F19%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fcasual-shirts-long%2F03'
r = Request(url)
r.add_header("user-agent", "Mozilla/5.0")
response = urlopen(r)
html = BeautifulSoup(response)
content2 = html.find_all('img', width="228")
content = html.find_all('a')

us = []
uss = []
for i in content:
    if i['href'] != '#':
        us.append(i['href'])
nm = len(us)

for m in range(1, int(nm/2+1)):

    uss.append(us[m*2-1])

cn = []
for i in content2:
    cn.append(i['title'][3:])
print(cn)

cnn = []
for i in content2:
    cnn.append(i['color_chip_image'])

import redis

r = redis.Redis(host='redis', port=6379, decode_responses=True)

for ii in range(len(content2)):
    r.set('uniqlo_襯衫_M_' + cn[ii] + '_' + str(ii), cn[ii] + '___' + cnn[ii].replace('http', 'https') + '___' + uss[ii])
    r.expire('uniqlo_襯衫_M_' + cn[ii] + '_' + str(ii), 108000)

url = 'http://www.uniqlo.com/tw/store/feature/uq/alias/v2/ajaxAliasItem.jsp?dispLayerInfo=%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshirts-and-blouses%2F01%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshirts-and-blouses%2F10%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshirts-and-blouses%2F02%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshirts-and-blouses%2F18%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshirts-and-blouses%2F21%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshirts-and-blouses%2F06%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshirts-and-blouses%2F04%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshirts-and-blouses%2F09%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshirts-and-blouses%2F08%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshirts-and-blouses%2F24%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshirts-and-blouses%2F17%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshirts-and-blouses%2F14'
r = Request(url)
r.add_header("user-agent", "Mozilla/5.0")
response = urlopen(r)
html = BeautifulSoup(response)
content2 = html.find_all('img', width="228")
content = html.find_all('a')

us = []
uss = []
for i in content:
    if i['href'] != '#':
        us.append(i['href'])
nm = len(us)

for m in range(1, int(nm/2+1)):

    uss.append(us[m*2-1])

cn = []
for i in content2:
    cn.append(i['title'][3:])
print(cn)

cnn = []
for i in content2:
    cnn.append(i['color_chip_image'])

import redis

r = redis.Redis(host='redis', port=6379, decode_responses=True)

for ii in range(len(content2)):
    r.set('uniqlo_襯衫_F_' + cn[ii] + '_' + str(ii), cn[ii] + '___' + cnn[ii].replace('http', 'https') + '___' + uss[ii])
    r.expire('uniqlo_襯衫_F_' + cn[ii] + '_' + str(ii), 108000)

url = 'http://www.uniqlo.com/tw/store/feature/uq/alias/v2/ajaxAliasItem.jsp?dispLayerInfo=%2Fftop%2Fuq%2Fmen%2Fouter%2Fjacket-and-coat%2F06%2C%2Fftop%2Fuq%2Fmen%2Fouter%2Fjacket-and-coat%2F12%2C%2Fftop%2Fuq%2Fmen%2Fouter%2Fjacket-and-coat%2F01%2C%2Fftop%2Fuq%2Fmen%2Fouter%2Fjacket-and-coat%2F18%2C%2Fftop%2Fuq%2Fmen%2Fouter%2Fjacket-and-coat%2F08%2C%2Fftop%2Fuq%2Fmen%2Fouter%2Fjacket-and-coat%2F17%2C%2Fftop%2Fuq%2Fmen%2Fouter%2Fjacket-and-coat%2F03%2C%2Fftop%2Fuq%2Fmen%2Fouter%2Fjacket-and-coat%2F07'
r = Request(url)
r.add_header("user-agent", "Mozilla/5.0")
response = urlopen(r)
html = BeautifulSoup(response)
content2 = html.find_all('img', width="228")
content = html.find_all('a')

us = []
uss = []
for i in content:
    if i['href'] != '#':
        us.append(i['href'])
nm = len(us)

for m in range(1, int(nm/2+1)):

    uss.append(us[m*2-1])

cn = []
for i in content2:
    cn.append(i['title'][3:])
print(cn)

cnn = []
for i in content2:
    cnn.append(i['color_chip_image'])

import redis

r = redis.Redis(host='redis', port=6379, decode_responses=True)

for ii in range(len(content2)):
    r.set('uniqlo_西裝外套_M_' + cn[ii] + '_' + str(ii), cn[ii] + '___' + cnn[ii].replace('http', 'https') + '___' + uss[ii])
    r.expire('uniqlo_西裝外套_M_' + cn[ii] + '_' + str(ii), 108000)

from urllib.request import urlopen, Request, urlretrieve
from bs4 import BeautifulSoup

url = 'http://www.uniqlo.com/tw/store/feature/uq/alias/v2/ajaxAliasItem.jsp?dispLayerInfo=%2Fftop%2Fuq%2Fwomen%2Ftops%2Fdresses%2F02%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fdresses%2F07%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fdresses%2F03%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fdresses%2F08%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fdresses%2F13%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fdresses%2F12%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fdresses%2F05%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fdresses%2F18%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fdresses%2F10'
r = Request(url)
r.add_header("user-agent", "Mozilla/5.0")
response = urlopen(r)
html = BeautifulSoup(response)
content2 = html.find_all('img', width="228")
content = html.find_all('a')

us = []
uss = []
for i in content:
    if i['href'] != '#':
        us.append(i['href'])
nm = len(us)

for m in range(1, int(nm/2+1)):

    uss.append(us[m*2-1])

cn = []
for i in content2:
    cn.append(i['title'][3:])
print(cn)

cnn = []
for i in content2:
    cnn.append(i['color_chip_image'])

import redis

r = redis.Redis(host='redis', port=6379, decode_responses=True)

for ii in range(len(content2)):
    r.set('uniqlo_洋裝_F_' + cn[ii] + '_' + str(ii), cn[ii] + '___' + cnn[ii].replace('http', 'https') + '___' + uss[ii])
    r.expire('uniqlo_洋裝_F_' + cn[ii] + '_' + str(ii), 108000)
    

from urllib.request import urlopen, Request, urlretrieve
from bs4 import BeautifulSoup

url = 'http://www.uniqlo.com/tw/store/feature/uq/alias/v2/ajaxAliasItem.jsp?dispLayerInfo=%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshort-sleeves-and-tank-top%2F07%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshort-sleeves-and-tank-top%2F02%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshort-sleeves-and-tank-top%2F03%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshort-sleeves-and-tank-top%2F13%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshort-sleeves-and-tank-top%2F06%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshort-sleeves-and-tank-top%2F10%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshort-sleeves-and-tank-top%2F09%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshort-sleeves-and-tank-top%2F04%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshort-sleeves-and-tank-top%2F01%2C%2Fftop%2Fuq%2Fwomen%2Ftops%2Fshort-sleeves-and-tank-top%2F15'
r = Request(url)
r.add_header("user-agent", "Mozilla/5.0")
response = urlopen(r)
html = BeautifulSoup(response)
content2 = html.find_all('img', width="228")
content = html.find_all('a')

us = []
uss = []
for i in content:
    if i['href'] != '#':
        us.append(i['href'])
nm = len(us)

for m in range(1, int(nm/2+1)):

    uss.append(us[m*2-1])

cn = []
for i in content2:
    cn.append(i['title'][3:])
print(cn)

cnn = []
for i in content2:
    cnn.append(i['color_chip_image'])

import redis

r = redis.Redis(host='redis', port=6379, decode_responses=True)

for ii in range(len(content2)):
    r.set('uniqlo_T-shirt&背心_F_' + cn[ii] + '_' + str(ii), cn[ii] + '___' + cnn[ii].replace('http', 'https') + '___' + uss[ii])
    r.expire('uniqlo_T-shirt&背心_F_' + cn[ii] + '_' + str(ii), 100800)

from urllib.request import urlopen, Request, urlretrieve
from bs4 import BeautifulSoup

url = 'http://www.uniqlo.com/tw/store/feature/uq/alias/v2/ajaxAliasItem.jsp?dispLayerInfo=%2Fftop%2Fuq%2Fmen%2Ftops%2Fshort-sleeves-and-tank-top%2F15%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fshort-sleeves-and-tank-top%2F04%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fshort-sleeves-and-tank-top%2F06%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fshort-sleeves-and-tank-top%2F11%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fshort-sleeves-and-tank-top%2F16%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fshort-sleeves-and-tank-top%2F01%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fshort-sleeves-and-tank-top%2F02%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fshort-sleeves-and-tank-top%2F03%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fshort-sleeves-and-tank-top%2F12%2C%2Fftop%2Fuq%2Fmen%2Ftops%2Fshort-sleeves-and-tank-top%2F13'
r = Request(url)
r.add_header("user-agent", "Mozilla/5.0")
response = urlopen(r)
html = BeautifulSoup(response)
content2 = html.find_all('img', width="228")
content = html.find_all('a')

us = []
uss = []
for i in content:
    if i['href'] != '#':
        us.append(i['href'])
nm = len(us)

for m in range(1, int(nm/2+1)):

    uss.append(us[m*2-1])

cn = []
for i in content2:
    cn.append(i['title'][3:])
print(cn)

cnn = []
for i in content2:
    cnn.append(i['color_chip_image'])

import redis

r = redis.Redis(host='redis', port=6379, decode_responses=True)

for ii in range(len(content2)):
    r.set('uniqlo_T-shirt&背心_M_' + cn[ii] + '_' + str(ii), cn[ii] + '___' + cnn[ii].replace('http', 'https') + '___' + uss[ii])
    r.expire('uniqlo_T-shirt&背心_M_' + cn[ii] + '_' + str(ii), 108000)
# Out:
# ['超柔棉府綢立領襯衫 (長袖)', '超柔棉府綢襯衫 (長袖)', '超柔棉府綢立領襯衫 (長袖)', '超柔棉府綢襯衫 (長袖)', '超柔棉府綢條紋襯衫 (長袖)', '超柔棉府綢條紋立領襯衫 (長袖)', '超柔棉府綢條紋襯衫 (長袖)', '超柔棉府綢條紋襯衫 (長袖)', '超柔棉府綢條紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (長袖)', '超柔棉府綢拼接襯衫 (長袖)', '超柔棉府綢印花襯衫 (長袖)', '超柔棉府綢印花襯衫 (長袖)', '超柔棉府綢印花襯衫 (長袖)', '超柔棉府綢印花襯衫 (長袖)', '牛仔襯衫 (長袖)', '水洗復古牛仔工作襯衫 (長袖)', '牛仔SLIM FIT襯衫 (長袖)', '牛津拼接襯衫 (長袖)', '牛津襯衫 (長袖)', '牛津襯衫 (長袖)', '牛津條紋襯衫 (長袖)', '牛津襯衫 (長袖)', '牛津襯衫 (長袖)', '牛津SLIM FIT襯衫 (長袖)', '牛津SLIM FIT襯衫 (長袖)', '特級亞麻襯衫 (長袖)', '特級亞麻寬版襯衫 (短袖)', '特級亞麻格紋寬版襯衫 (短袖)', '特級亞麻格紋寬版襯衫 (短袖)', '特級亞麻條紋襯衫 (長袖)', '特級亞麻條紋襯衫 (長袖)', '特級亞麻格紋襯衫 (長袖)', '特級亞麻格紋襯衫 (長袖)', '特級亞麻格紋襯衫 (長袖)', '超柔棉府綢格紋襯衫 (短袖)', '超柔棉府綢立領襯衫 (短袖)', '超柔棉府綢格紋襯衫 (短袖)', '超柔棉府綢條紋襯衫 (短袖)', '超柔棉府綢格紋襯衫 (短袖)', '棉麻襯衫 (短袖)', 'DRY泡泡
# ...
